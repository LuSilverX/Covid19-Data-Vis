# %%
import pandas as pd
import os

DATA_DIR = '../data'

covid_data = pd.read_csv(os.path.join(DATA_DIR, 'us-counties.csv'))

covid_data.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
# Checking the shape of the dataset
print("Dataset Shape:", covid_data.shape)

# Getting information about data types and missing values
covid_data.info()
# Out:
# Dataset Shape: (67456, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67456 entries, 0 to 67455
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    67456 non-null  object
#  1   county  67456 non-null  object
#  2   state   67456 non-null  object
#  3   fips    66585 non-null  float64
#  4   cases   67456 non-null  int64
#  5   deaths  67456 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.1+ MB

# %%
# Getting summary statistics
covid_data.describe()
# Out:
#                fips          cases        deaths
# count  66585.000000   67456.000000  67456.000000
# mean   29644.277795     132.075738      4.642004
# std    15516.287093    1643.795202     93.594603
# min     1001.000000       0.000000      0.000000
# 25%    17195.000000       2.000000      0.000000
# 50%    28147.000000       7.000000      0.000000
# 75%    44003.000000      27.000000      1.000000
# max    56043.000000  127352.000000   8632.000000

# %%
# Total missing values per column
covid_data.isnull().sum()
# Out:
# date        0
# county      0
# state       0
# fips      871
# cases       0
# deaths      0
# dtype: int64
