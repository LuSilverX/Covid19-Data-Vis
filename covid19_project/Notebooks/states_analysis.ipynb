# %%
import pandas as pd
import os

DATA_DIR = '../data'

states_data = pd.read_csv(os.path.join(DATA_DIR, 'us-states.csv'))

states_data.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
# Shape of the dataset
print("Dataset Shape:", states_data.shape)

# Info on data types and missing values
states_data.info()
# Out:
# Dataset Shape: (2553, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2553 non-null   object
#  1   state   2553 non-null   object
#  2   fips    2553 non-null   int64
#  3   cases   2553 non-null   int64
#  4   deaths  2553 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 99.9+ KB

# %%
# Summary statistics
states_data.describe()
# Out:
#               fips          cases        deaths
# count  2553.000000    2553.000000   2553.000000
# mean     31.266353    3489.975715    122.910302
# std      18.271924   14882.179293    689.583118
# min       1.000000       0.000000      0.000000
# 25%      17.000000      13.000000      0.000000
# 50%      31.000000     235.000000      3.000000
# 75%      46.000000    1550.000000     36.000000
# max      78.000000  229642.000000  12822.000000

# %%
# Total missing values per column
states_data.isnull().sum()
# Out:
# date      0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64
