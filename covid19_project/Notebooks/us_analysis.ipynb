# %%
import pandas as pd
import os

DATA_DIR = '../data'

us_data = pd.read_csv(os.path.join(DATA_DIR, 'us.csv'))

us_data.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
print("Dataset Shape:", us_data.shape)

# Data types and missing values
us_data.info()
# Out:
# Dataset Shape: (88, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    88 non-null     object
#  1   cases   88 non-null     int64
#  2   deaths  88 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 2.2+ KB

# %%
# Summary statistics
us_data.describe()
# Out:
#                cases        deaths
# count      88.000000     88.000000
# mean   101248.954545   3565.795455
# std    191573.038134   7825.018121
# min         1.000000      0.000000
# 25%        13.750000      0.000000
# 50%       194.500000     12.000000
# 75%     89841.250000   1368.500000
# max    699852.000000  32914.000000

# %%
# Total missing values per column
us_data.isnull().sum()
# Out:
# date      0
# cases     0
# deaths    0
# dtype: int64
